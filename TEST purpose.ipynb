# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
game_sales = pd.read_csv('game_sales.csv')

# %%
game_sales_sub = game_sales.loc[game_sales['Rating'].isin(['T','E','M','E10+'])]

# %% [markdown]
# # This barplot is perfect

# %%
sns.barplot(data=game_sales_sub,x='Rating',y='Critic_Score',ci=None);
plt.ylim(60,80)
plt.grid()

# %% [markdown]
# # I can see the last bar but not the variable name for it.

# %%
g = sns.FacetGrid(data=game_sales_sub,col='Platform',col_wrap=6);
g.map(plt.hist,'Rating')

# %% [markdown]
# # But this one is bit different, I can't even see last bar.

# %%
g = sns.FacetGrid(data=game_sales_sub,col='Platform',col_wrap=6);
g.map(sns.barplot,'Rating','Critic_Score',ci=None)
plt.ylim(60,80)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# (60.0, 80.0)
